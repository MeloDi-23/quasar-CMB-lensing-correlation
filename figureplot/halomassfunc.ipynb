# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.size'] = 15

# %%
func = np.load('/uufs/astro.utah.edu/common/home/u6060319/quasar-CMBlening/mcmc/python/halo_mass_function.npy')

# %%
plt.plot(func['Mass'], func['nh'])
plt.semilogy()

plt.xlabel(r'$\lg (M_h/h^{-1}M_\odot)$')
plt.ylabel(r'$\frac{\mathrm{d} n_h}{\mathrm{d} \lg M_h}[h^3 \mathrm{Mpc}^{-3}]$')

# plt.savefig('/uufs/astro.utah.edu/common/home/u6060319/quasar-CMBlening/figure/nh.pdf')
# Out:
# Text(0, 0.5, '$\\frac{\\mathrm{d} n_h}{\\mathrm{d} \\lg M_h}[h^3 \\mathrm{Mpc}^{-3}]$')
