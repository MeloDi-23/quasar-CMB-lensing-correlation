# %%
import numpy as np
import seaborn as sns

# %%
halo = np.loadtxt('haloinfo_zspace.dat', dtype=[('id', int), ('id1', int), ('id2', int), ('M_h', float), ('X', float), ('Y', float), ('Z', float)])

# %%
halo1 = halo[63:]

# %%
index = ((halo1['id1'] != -1) | (halo1['id2'] != -1))

# %%
main_halo = halo1[~index]

# %%
len(main_halo)
# Out:
# 136876009

# %%
main_halo_final = np.zeros(len(main_halo), dtype=[('id', int), ('M_h', float), ('X', float), ('Y', float), ('Z', float)])

# %%
for k in main_halo_final.dtype.names:
    main_halo_final[k] = main_halo[k]

# %%
np.log10(main_halo_final['M_h'].min())
# Out:
# 10.67250424130091

# %%
np.log10(main_halo_final['M_h'].max())
# Out:
# 14.708293397717032

# %%
np.save('main_halo_zspace', main_halo_final)

# %%
main_halo = np.load('main_halo_zspace.npy')

# %%
len(main_halo_final)
# Out:
# 136876009

# %%
sns.histplot(np.log10(main_halo_final['M_h']), binrange=(11, 14.7), binwidth=0.01)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log10(main_halo_final['M_h']), binrange=(11, 14.7), binwidth=0.05)
# Out:
# <Axes: ylabel='Count'>

# %%
np.log10(main_halo_final['M_h'].max())
# Out:
# 14.708293397717032

# %%
logMh_m = 11.5
logMh_M = 15
logMh_bin = 0.02
logMh_N = int((logMh_M - logMh_m) / logMh_bin)

bins = np.linspace(logMh_m, logMh_M, logMh_N)
res = np.digitize(np.log10(main_halo['M_h']), bins)

# %%
count = np.bincount(res)

# %%
count
# Out:
# array([20873163,  8563271,  4745494, 13594947,  7891547,  9759227,
#         7847379,  6435027,  6946466,  5572615,  5586046,  4463672,
#         4290656,  3955570,  3144881,  3198007,  2758443,  2177951,
#         2214078,  1723498,  1560919,  1445046,  1180224,  1055858,
#          887154,   796776,   673539,   566474,   494500,   423689,
#          357040,   306395,   254525,   214411,   179349,   147559,
#          122648,   101015,    82108,    66482,    54099,    42725,
#           31634,    22745,    17558,    13384,    10014,     7625,
#            5452,     4129,     2848,     2040,     1482,     1019,
#             629,      365,      225,      166,      102,       57,
#              30,       13,       10,        6,        3])

# %%
len(count)
# Out:
# 65

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(count)
