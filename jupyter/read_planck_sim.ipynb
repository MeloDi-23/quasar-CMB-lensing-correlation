# %%
from astropy.io import fits
import healpy as hp
import matplotlib.pyplot as plt
import numpy as np

# %%
klm_sim = hp.read_alm('/uufs/chpc.utah.edu/common/home/astro/zheng/hd/data/Planck_sim/MV/sim_klm_001.fits')
cl_sim = hp.alm2cl(klm_sim, lmax_out=2048)
plt.plot(cl_sim)
plt.loglog()
# Out:
# []

# %%
nlkk = np.loadtxt('/uufs/chpc.utah.edu/common/home/astro/zheng/hd/data/Planck_sim/MV/nlkk.dat')

# %%
clkk = np.loadtxt('/uufs/chpc.utah.edu/common/home/astro/zheng/hd/data/Planck_sim/inputs/clkk.dat')

# %%
for i in range(1, 7):
    plt.plot(nlkk[:,0], nlkk[:,i], label=f'col {i}')
plt.legend()
plt.loglog()
# Out:
# []

# %%
plt.plot(clkk[:,0], clkk[:,1])
