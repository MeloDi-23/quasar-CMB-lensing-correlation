# %%
from astropy.io import fits

# %%
quasar_cata = fits.open('../data/SDSS16Q/DR16Q_v4.fits')

# %%
len(quasar_cata)
# Out:
# 2

# %%
quasar_cata[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 2290 / length of dimension 1
# NAXIS2  =               750414 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                  183 / number of table fields
# TTYPE1  = 'SDSS_NAME'
# TFORM1  = '18A     '
# TTYPE2  = 'RA      '
# TFORM2  = 'D       '
# TTYPE3  = 'DEC     '
# TFORM3  = 'D       '
# TTYPE4  = 'PLATE   '
# TFORM4  = 'J       '
# TTYPE5  = 'MJD     '
# TFORM5  = 'J       '
# TTYPE6  = 'FIBERID '
# TFORM6  = 'I       '
# TTYPE7  = 'AUTOCLASS_PQN'
# TFORM7  = '6A      '
# TTYPE8  = 'AUTOCLASS_DR14Q'
# TFORM8  = '6A      '
# TTYPE9  = 'IS_QSO_QN'
# TFORM9  = 'I       '
# TTYPE10 = 'Z_QN    '
# TFORM10 = 'D       '
# TTYPE11 = 'RANDOM_SELECT'
# TFORM11 = 'I       '
# ...

# %%
quasar_cata[1].data.dtype
# Out:
# dtype((numpy.record, [('SDSS_NAME', 'S18'), ('RA', '>f8'), ('DEC', '>f8'), ('PLATE', '>i4'), ('MJD', '>i4'), ('FIBERID', '>i2'), ('AUTOCLASS_PQN', 'S6'), ('AUTOCLASS_DR14Q', 'S6'), ('IS_QSO_QN', '>i2'), ('Z_QN', '>f8'), ('RANDOM_SELECT', '>i2'), ('Z_10K', '>f8'), ('Z_CONF_10K', '>i2'), ('PIPE_CORR_10K', '>i2'), ('IS_QSO_10K', '>i2'), ('THING_ID', '>i8'), ('Z_VI', '>f8'), ('Z_CONF', '>i2'), ('CLASS_PERSON', '>i2'), ('Z_DR12Q', '>f8'), ('IS_QSO_DR12Q', '>i2'), ('Z_DR7Q_SCH', '>f8'), ('IS_QSO_DR7Q', '>i2'), ('Z_DR6Q_HW', '>f8'), ('Z_DR7Q_HW', '>f8'), ('IS_QSO_FINAL', '>i2'), ('Z', '>f8'), ('SOURCE_Z', 'S12'), ('Z_PIPE', '>f8'), ('ZWARNING', '>i4'), ('OBJID', 'S19'), ('Z_PCA', '>f8'), ('ZWARN_PCA', '>i8'), ('DELTACHI2_PCA', '>f8'), ('Z_HALPHA', '>f8'), ('ZWARN_HALPHA', '>i8'), ('DELTACHI2_HALPHA', '>f8'), ('Z_HBETA', '>f8'), ('ZWARN_HBETA', '>i8'), ('DELTACHI2_HBETA', '>f8'), ('Z_MGII', '>f8'), ('ZWARN_MGII', '>i8'), ('DELTACHI2_MGII', '>f8'), ('Z_CIII', '>f8'), ('ZWARN_CIII', '>i8'), ('
# ...

# %%
data = quasar_cata[1].data
ra = data['RA']
dec = data['DEC']
z = data['Z']

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(z[z>0])
# Out:
# (array([5.26210e+04, 2.16237e+05, 2.43863e+05, 1.77961e+05, 4.94800e+04,
#         8.32300e+03, 1.21500e+03, 2.96000e+02, 2.04000e+02, 2.04000e+02]),
#  array([6.90759334e-04, 7.03013403e-01, 1.40533605e+00, 2.10765869e+00,
#         2.80998133e+00, 3.51230398e+00, 4.21462662e+00, 4.91694927e+00,
#         5.61927191e+00, 6.32159455e+00, 7.02391720e+00]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.histplot(x=ra.astype('float'), y=dec.astype('float'))
# Out:
# <AxesSubplot:>
