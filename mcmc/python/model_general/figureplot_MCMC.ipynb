# %% [markdown]
# this file plots the main MCMC result.

# %%
import numpy as np
import corner
import matplotlib.pyplot as plt
import seaborn as sns
from emcee.backends import HDFBackend
from read_files import *
from run_mcmc import HODParameter

# %%
with open('./configs/config_small_step_pow.yaml', 'r') as f:
    par_configs, other_configs = list(yaml.load_all(f, yaml.FullLoader))
    # ========== reading configs ==========
    available_fields = ['Nwalkers', 'Nstep', 'Nburnin', 'Npro', 'auto_range', 'cross_range',
                        'backend_file', 'numpy_file', 'wp_table_path', 'signal_path', 'module_path']
    Nwalkers = 40
    Nstep = 4000
    Nburnin = 300
    Npro = 40
    auto_range = None
    cross_range = None
    backend_file = ''
    numpy_file = ''
    wp_table_path = '../wp_table'
    signal_path = '../signal'
    module_path = './HOD/calc_wp.py'

    for k in available_fields:
        if k in other_configs:
            locals()[k] = other_configs[k]

    wp_table = read_wp(wp_table_path)
    rp_auto, signal_auto, rp_cross, signal_cross = read_signal(signal_path + '/signal.npy')
    cov = read_cov(signal_path + '/cov.npy')
    logM, Nh = read_halo_mass_function('../halo_mass_function.npy')
    module = read_module(module_path)
    chi_2 = module.chi_2
    N_c = module.N_c
    # ========== apply the fitting range ==========

    if auto_range or cross_range:
        if auto_range is None:
            auto_range = [0, len(rp_auto)]
        if cross_range is None:
            cross_range = [0, len(rp_cross)]
        l_a, r_a = auto_range[0], auto_range[1]
        l_c, r_c = cross_range[0], cross_range[1]

        auto_size = len(rp_auto)
        cross_size = len(rp_cross)
        rp_auto = rp_auto[l_a:r_a]
        rp_cross = rp_cross[l_c:r_c]
        signal_auto = signal_auto[l_a:r_a]
        signal_cross = signal_cross[l_c:r_c]

        cov = np.vstack((
            np.hstack((cov[l_c:r_c, l_c:r_c], cov[l_c:r_c, cross_size+l_a:cross_size+r_a])),
            np.hstack((cov[cross_size+l_a:cross_size+r_a, l_c:r_c], cov[cross_size+l_a:cross_size+r_a, cross_size+l_a:cross_size+r_a]))
        ))

    signal = np.hstack((signal_cross, signal_auto))
    cov_inv = np.linalg.inv(cov)

    # ========== handle interpolating table ==========
    wp_table_auto = interpolate_table(wp_table, rp_auto)
    wp_table_cross = interpolate_table(wp_table, rp_cross)

    parameter = HODParameter.from_config(par_configs)
    dof = len(signal) - parameter.ndim - np.isnan(signal).sum()
    print(parameter)
    print('dof = {}'.format(dof))
    print(dof + np.sqrt(2*dof)*1.96)
# Out:
# HODParameter(lgMmin:    14  [10~17]
#              sig_lgM:   0.5 [0.001~1]
#              Amp:       1   [fixed]
#              lgM0:      12  [11~16]
#              lgM1p:     12  [10.5~16]
#              alpha:     1   [0~5])
# dof = 29
# 43.92691528749326

# %%
if not numpy_file.endswith('.npy'):
    numpy_file += '.npy'
result = np.load(numpy_file)
array_2d = result.view((np.float64, len(result.dtype.names)))
backend = HDFBackend(backend_file, read_only=True)
chain = backend.get_chain(flat=True, discard=5000)
# chi2 = -backend.get_log_prob(flat=True, discard=5000)*2
blobs = backend.get_blobs(discard=5000, flat=True)

# %%
chain_plot = backend.get_chain(flat=True, discard=5000, thin=200)

# chain_plot = chain_plot[chain_plot[:,1] < 0.3,:]
# fig = corner.corner(chain_plot, labels=[
#     r'$\lg M_{\text{min}}$',
#     r'$\sigma_{\lg M}$',
#     r'$\lg M_0$',
#     r"$\lg M_1 '$",
#     r'$\alpha$'], show_titles=True, color='orange', 
#     truths=np.percentile(chain_plot, 50, axis=0), 
#     smooth=0.7)

ranges = [(11.6, 14.0),   # lgMmin
            (0.0, 1.0),    # sigma
          (11.0, 16.0),   # lgM0
          (11.0, 16.0),   # lgM1p
          (0.0, 5.0)]     # alpha

fig = corner.corner(chain_plot,
                    labels=[r'$\log M_{\text{min}}$',
                            r'$\sigma_{\log M}$',
                            r'$\log M_0$',
                            r"$\log M_1 '$",
                            r'$\alpha$'],
                    show_titles=True,
                    range=ranges,
                    color='orange',
                    truths=np.percentile(array_2d, 50, axis=0),
                    smooth=0.7,
                    quantiles=[0.16, 0.5, 0.84],
                    plot_contours=True,
                    levels=[0.393, 0.864],
                    plot_datapoints=False,
                    plot_density=True,
                    pcolor_kwargs={'edgecolors': 'none'},
                #     contour_kwargs={'colors': 'red'}
                    )
# plt.savefig('auto.pdf')

plt.show()

# %%
blobs = backend.get_blobs(discard=5000, thin=500, flat=True)

# %%
d, m, u = np.percentile(blobs['amp'], [50-34.1, 50, 50+34.1])
print('{}-{}+{}'.format(m, m-d, u-m))
axe = sns.histplot(blobs['amp'], bins=40, stat='density', linewidth=0, color='orange', fill=True)
axe.set_xlabel('$A$')
bottom, top = axe.get_ylim()
axe.vlines([d, u], bottom, top, colors='blue', linestyles='dashed')
axe.vlines([m], bottom, top, colors='blue', linestyles='solid')
# Out:
# 0.01019774871333487-0.0036613648564499677+0.008184852311311872

# %%
dat = blobs['fsat']#[chi2 < np.percentile(chi2, 50)]
d, m, u = np.percentile(dat, [50-34.1, 50, 50+34.1])
print('{}-{}+{}'.format(m, m-d, u-m))
axe = sns.histplot(dat, bins=40, stat='density', linewidth=0, color='orange', fill=True)
axe.set_xlabel(r'$f_{\text{sat}}$')
bottom, top = axe.get_ylim()
axe.vlines([d, u], bottom, top, colors='blue', linestyles='dashed')
axe.vlines([m], bottom, top, colors='blue', linestyles='solid')
# Out:
# 0.08990144638889642-0.08990143159962512+0.17232720136196472

# %%
chain_plot = backend.get_chain(discard=5000, thin=500, flat=True)
# chain = backend.get_chain(discard=5000, flat=True)

# %%
fig = corner.corner(chain_plot, labels=[
    r'$\lg M_{\text{min}}$',
    r'$\sigma_{\lg M}$',
    r'$\lg M_0$',
    r"$\lg M_1 '$",
    r'$\alpha$'], show_titles=True, color='orange', 
    truths=np.percentile(array_2d, 50, axis=0), smooth=0.7)
plt.show()

# %%
chain = backend.get_chain(flat=True, discard=5000, thin=500)
blobs = backend.get_blobs(discard=5000, thin=500, flat=True)
chi2 = -backend.get_log_prob(flat=True, discard=5000, thin=500)*2

# %%
import tqdm
ncs = []
nss = []
res = chain
for c in tqdm.tqdm(res):
    par = parameter.full_parameters(c)
    ncs.append(module.N_c(logM, par))
    nss.append(module.N_s(logM, par))
ncs = np.array(ncs)
nss = np.array(nss)
# Out:
# 100%|██████████| 2500/2500 [00:00<00:00, 3254.77it/s]

# %%
ncs1 = ncs * (blobs['amp'].reshape((-1, 1)) @ np.ones(shape=(1, ncs.shape[1])))
nss1 = ncs * nss * (blobs['amp'].reshape((-1, 1)) @ np.ones(shape=(1, ncs.shape[1])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ncs1 = ncs * (blobs['amp'].reshape((-1, 1)) @ np.ones(shape=(1, ncs.shape[1])))
#       2 nss1 = ncs * nss * (blobs['amp'].reshape((-1, 1)) @ np.ones(shape=(1, ncs.shape[1])))
#
# NameError: name 'ncs' is not defined

# %%
nc = np.percentile(ncs1, 50, axis=0)
ns = np.percentile(nss1, 50, axis=0)

ncu = np.percentile(ncs1, 50+34.1, axis=0)
nsu = np.percentile(nss1, 50+34.1, axis=0)
ncd = np.percentile(ncs1, 50-34.1, axis=0)
nsd = np.percentile(nss1, 50-34.1, axis=0)

# ncu = ncs1.max(axis=0)
# nsu = nss1.max(axis=0)
# ncd = ncs1.min(axis=0)
# nsd = nss1.min(axis=0)

plt.plot(logM, nc, label='$N_c$')
plt.plot(logM, ns, label='$N_s$')
plt.fill_between(logM, ncd, ncu, alpha=0.3)
plt.fill_between(logM, nsd, nsu, alpha=0.3)
plt.semilogy()
plt.ylim(bottom=1e-3)

plt.xlabel('$M_h$')
plt.legend()
plt.show()

# Nc = (nc*Nh).sum()
# Ns = (nc*ns*Nh).sum()

# print('Nq = {}'.format(Nc+Ns))
# print('fsat = {}'.format(Ns/(Nc+Ns)))

# %%
par = parameter.full_parameters(np.percentile(array_2d, 50, axis=0))

# %%
predict = module.w_p(logM, Nh, par, wp_table_auto, wp_table_cross)
pre_cross = predict[:len(rp_cross)]
pre_auto = predict[len(rp_cross):]
std = np.sqrt([cov[i, i] for i in range(len(signal))])
err_cross = std[:len(rp_cross)]
err_auto = std[len(rp_cross):]
plt.errorbar(rp_auto, signal_auto, err_auto, fmt='r', capsize=2, label='auto correlation')
plt.errorbar(rp_cross, signal_cross, err_cross, fmt='g>', capsize=2, label='cross correlation')
plt.plot(rp_auto, pre_auto, 'r--')
plt.plot(rp_cross, pre_cross, 'g--')
plt.xlabel(r'$r_p[h^{-1}\mathrm{Mpc}]$')
plt.ylabel(r'$w_p[h^{-1}\mathrm{Mpc}]$')
plt.legend()
plt.loglog()
# Out:
# []

# %%
print(((pre_auto - signal_auto) / err_auto)**2)
print(((pre_cross - signal_cross) / err_cross)**2)
print(np.nan_to_num(((pre_auto - signal_auto) / err_auto)**2).sum(), (((pre_cross - signal_cross) / err_cross)**2).sum())
# Out:
# [2.95535287e-01 3.31442975e-02 7.25752545e-02 3.56381995e+00
#  2.76255590e-01            nan 3.79357019e-01 1.37687000e+00
#  2.99418022e+00 2.28227598e-01 2.07173782e+00 1.25527656e+00
#  6.81520801e-02 4.96360660e-03 5.77577056e-01 8.27302289e-01
#  3.59296495e+00 1.91472365e-01 1.25568195e-01 1.74035104e+00
#  1.90753001e+00 1.24321525e-01 1.13366523e+01 8.82073011e+00
#  2.01658948e+00]
# [1.18282031e-01 9.92349623e-02 3.54734933e+00 1.89772719e+00
#  2.39187216e-01 2.92901330e-01 2.53191492e-01 1.29399035e+00
#  1.60332890e+00 8.44715257e-02 1.88501951e+00 6.05123827e-02
#  4.16543791e-07]
# 43.88115456768998 11.375196638769156

# %%
N_g = (module.N_c(logM, par) + module.N_s(logM, par)) * Nh

weights = np.nan_to_num(N_g, nan=0.0)
total = weights.sum()
if total == 0:
    median_logM = np.nan
else:
    cdf = np.cumsum(weights) / total
    median_logM = np.interp(0.5, cdf, logM)

median_M = 10**median_logM
print(f"median logM = {median_logM}")
print(f"median M = {median_M}")
# Out:
# median logM = 12.427835796830678
# median M = 2678155544799.1914

# %%
import tqdm

med_logM = []
ngs = []

res = chain
for c in tqdm.tqdm(res):
    par = parameter.full_parameters(c)
    N_g = (module.N_c(logM, par) + module.N_s(logM, par)) * Nh
    weights = np.nan_to_num(N_g, nan=0.0)
    total = weights.sum()
    if total == 0:
        median_logM = np.nan
    else:
        cdf = np.cumsum(weights) / total
        median_logM = np.interp(0.5, cdf, logM)
    ngs.append(N_g)
    med_logM.append(median_logM)
# Out:
# 100%|██████████| 1250000/1250000 [06:11<00:00, 3368.87it/s]

# %%
logM.size
# Out:
# 161

# %%
ngs = np.array(ngs)
ng_m = np.percentile(ngs, 50, axis=0)
ng_u = np.percentile(ngs, 50+34.1, axis=0)
ng_d = np.percentile(ngs, 50-34.1, axis=0)

plt.plot(logM, ng_m)
plt.fill_between(logM, ng_d, ng_u, alpha=0.3)
plt.xlabel(r'$\log M_h$')
plt.ylabel(r'$N_g$')
plt.show()

# %%
per_res = np.percentile(med_logM, [16, 50, 84])

print('Median logM: {:.2f} - {:.2f} + {:.2f}'.format(per_res[1], per_res[1]-per_res[0], per_res[2]-per_res[1]))
# Out:
# Median logM: 12.43 - 0.05 + 0.04

# %%
plt.plot(logM, (module.N_c(logM, par) + module.N_s(logM, par)) * Nh)

# %%
module.N_c(logM, par)
# Out:
# array([0.00731273, 0.0083127 , 0.0094308 , 0.01067827, 0.01206706,
#        0.01360982, 0.0153199 , 0.01721132, 0.01929877, 0.02159758,
#        0.02412363, 0.02689336, 0.02992368, 0.03323191, 0.0368357 ,
#        0.04075292, 0.04500158, 0.04959972, 0.05456528, 0.05991596,
#        0.06566912, 0.0718416 , 0.07844957, 0.08550839, 0.09303245,
#        0.10103499, 0.10952795, 0.11852181, 0.12802543, 0.13804589,
#        0.14858834, 0.15965589, 0.17124946, 0.18336767, 0.19600675,
#        0.20916046, 0.22282002, 0.23697407, 0.25160866, 0.26670723,
#        0.28225068, 0.29821734, 0.31458313, 0.33132157, 0.34840398,
#        0.36579956, 0.38347558, 0.40139754, 0.4195294 , 0.43783377,
#        0.45627217, 0.47480523, 0.49339298, 0.51199509, 0.53057113,
#        0.54908086, 0.56748445, 0.58574276, 0.60381761, 0.62167196,
#        0.63927021, 0.65657835, 0.67356419, 0.69019754, 0.70645032,
#        0.72229675, 0.73771343, 0.75267945, 0.76717642, 0.78118853,
#        0.7947026 , 0.80770801, 0.82019673, 0.83216324, 0.84360446,
#        0.8545197 , 0.86491052, 0.87478063, 0.88413577, 0.89298353,
#        0.90133328, 0.90919591, 0.91658378, 0.92351046, 0.92999065,
#        0.93603995, 0.94167476, 0.94691207, 0.95176936, 0.9562644 ,
#        0.96041519, 0.96423976, 0.96775609, 0.97098201, 0.97393508,
#        0.9766325 , 0.97909104, 0.98132701, 0.98335613, 0.98519353,
#        0.98685372, 0.98835053, 0.98969711, 0.99090591, 0.99198866,
#        0.99295641, 0.99381948, 0.99458754, 0.99526955, 0.99587384,
#        0.9964081 , 0.99687943, 0.99729433, 0.99765877, 0.99797818,
#        0.99825753, 0.9985013 , 0.99871357, 0.99889801, 0.99905791,
#        0.99919624, 0.99931566, 0.99941851, 0.99950691, 0.99958273,
#        0.99964761, 0.999703  , 0.99975021, 0.99979034, 0.99982438,
#        0.9998532 , 0.99987754, 0.99989805, 0.99991531, 0.99992979,
#        0.99994191, 0.99995204, 0.99996048, 0.99996751, 0.99997334,
#        0.99997817, 0.99998216, 0.99998546, 0.99998816, 0.99999039,
#        0.99999221, 0.9999937 , 0.99999492, 0.99999591, 0.99999671,
#        0.99999736, 0.99999789, 0.99999831, 0.99999866, 0.99999893,
#        0.99999915, 0.99999933, 0.99999947, 0.99999958, 0.99999967,
#        0.99999974])
